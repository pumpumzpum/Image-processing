# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image_normlung = cv2.imread('normal lung.jpeg')
plt.imshow(cv2.cvtColor(image_normlung, cv2.COLOR_BGR2RGB))
fig = plt.gcf()
fig.set_size_inches(10.5, 4.5)
plt.axis('off')
# Out:
# (-0.5, 1856.5, 1316.5, -0.5)

# %%
image_pneumolung = cv2.imread('pneumonia lung.jpeg')
plt.imshow(cv2.cvtColor(image_pneumolung, cv2.COLOR_BGR2RGB))
fig = plt.gcf()
fig.set_size_inches(10.5, 4.5)
plt.axis('off')
# Out:
# (-0.5, 951.5, 639.5, -0.5)

# %% [markdown]
# ## Resize image

# %%
import cv2
 
img = cv2.imread('pneumonia lung.jpeg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
cv2.imwrite('normal_resize.jpeg',resized) 
print('Resized Dimensions : ',resized.shape)
 
#cv2.imshow("Resized image", resized)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (640, 952)
# Resized Dimensions :  (384, 571)

# %%
# read a image using imread
img = cv2.imread('pneumonia_resize.jpeg', 0)

# creating a Histograms Equalization
# of a image using cv2.equalizeHist()
equ = cv2.equalizeHist(img)

# stacking images side-by-side
res = np.hstack((img, equ))

# show image input vs output
cv2.imshow('pneumonia_resize.jpeg', res)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## อันนี้ผมลอง resize เพราะหน้าจอมันเล็กเกินมันเปรียบเทียบซ้อนกันข้างๆได้ไม่เต็มภาพครับ

# %% [markdown]
# ## Histogram Equalization : pneumonia lung

# %%
img_pneumonia = cv2.imread('pneumonia lung.jpeg', 0)

equ_pneumonia = cv2.equalizeHist(img) #Histogram Equalization

plt.subplot(121)
plt.imshow(cv2.cvtColor(img_pneumonia, cv2.COLOR_BGR2RGB))
plt.title('Original Image', fontsize=20)
fig = plt.gcf()
fig.set_size_inches(10.5, 4.5)
plt.axis('off')


plt.subplot(122)
plt.imshow(cv2.cvtColor(equ_pneumonia, cv2.COLOR_BGR2RGB))
plt.title('Enhanced Image', fontsize=20)
fig = plt.gcf()
fig.set_size_inches(16.5, 8.5)
plt.axis('off')
cv2.imwrite('equlize_his+pneumonia.jpeg',equ_pneumonia)
# Out:
# True

# %% [markdown]
# ## Histogram Equalization : Normal lung

# %%
img_normal = cv2.imread('normal lung.jpeg', 0)

equ_normal = cv2.equalizeHist(img_normal) #Histogram Equalization

plt.subplot(121)
plt.imshow(cv2.cvtColor(img_normal, cv2.COLOR_BGR2RGB))
plt.title('Original Image', fontsize=20)
fig = plt.gcf()
fig.set_size_inches(10.5, 4.5)
plt.axis('off')


plt.subplot(122)
plt.imshow(cv2.cvtColor(equ_normal, cv2.COLOR_BGR2RGB))
plt.title('Enhanced Image', fontsize=20)
fig = plt.gcf()
fig.set_size_inches(16.5, 8.5)
plt.axis('off')
cv2.imwrite('equlize_his+normal.jpeg',equ_normal)
# Out:
# True

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### การทำ Histogram Equalization คือ การทำให้ภาพมีการกระจายตัวความเข้มแสงอย่างสม่ำเสมอในแต่ละจุด ซึ่งทำให้ข้อมูลที่ผ่านการแปลงแล้วมีการกระจายอย่างสม่ำเสมอโดยสามารถอธิบายได้จากกราฟ Histogram ที่จะเรียงตัวกันอย่างสม่ำเสมอ

# %% [markdown]
# ### ซึ่งรูปภาพที่ผมนำมาใช้จะเป็นรูปภาพ x-rays ปอด
#
# ### ที่มีอยู่ในทั้งสภาพปกติ และสภาพที่เป็นโรคปอดอักเสบ
#
# ### ซึ่งเมื่อลองเปรียบเทียบภาพหลังจากที่ทำ Histogram Equalization แล้วทำให้ภาพมีความเข้มแสงที่ชัดเจนขึ้นในจุดภาพที่เป็นโครงร่างส่วนประกอบต่างๆในร่างกายและปอด
#
# ### ทำให้ดูเหมือนภาพมีความคมชัดขึ้น ซึ่งหากมีการปรับปรุงภาพให้คมชัดขึ้นแบบนี้แล้ว เวลาที่แพทย์นำมาวินิจฉัยโรคเบื้องต้นนั้นจะสามารถลดความผิดพลาดในการวินิจฉัยได้
